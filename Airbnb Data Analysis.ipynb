# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Navjot Singh**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.
#
# - In the exploration of the Airbnb dataset, I dove into a vast sea of information that holds the information of different room listings on the Airbnb platform in New York. With around 49,000 observations and 16 columns, this dataset opened doors to understanding how Airbnb operates and Airbnb's ecosystem.
# - First off all, I found some hosts who are like big sharks on Airbnb with listing over more than 300 rooms. It's like discovering the top players of the industry they are the ones who really know how to make the most out of Airbnb.
# - Then i looked into the neighbouhood_group to figure out which neighbourhoods are the exciting places. Manhattan and Brooklyn turned out to be the coolest spots, each having over more than 20,000 listings. It's like the locations where most of users want to stay.
# - I also checked out the types of room people like. "Entire home/apt" and "Private room" stole the spotlight, each having over more than 20,000 listings. It's like realizing everyone has their favorite type of stay, and Airbnb has something for everyone.
# - Then some numbers came into play as i looked at the distribution of prices. Most listings, it turns out, fall in the range of $0 to $400. Understanding these price dynamics gives me a sense of what is affordable and popular on Airbnb.
# - Going a bit deeper and i looked into price column to find out how prices change in different neighborhoods. Surprisingly i find out how certain places ask for fancier prices than others. And when i looked at different types of rooms, a pattern came up that "Entire home/apt" listings usually cost more than private or shared rooms.
# - Next, I bring little bit of geography, I mapped out the locations of listings using latitude and longitude columns. It's like creating a visual travelogue, allowing me to see where in the world people are sharing their spaces.
# - As I reached the end of my analysis, I used pair plots and heatmaps to find out how different things are connected. It's like discovering secret pathways in a maze, helping me to understand the hidden relationships in the data.
# - In essence, my Airbnb data exploration wasn't just about numbers and columns. It was a story behind each listing, the choices hosts make, and the preferences of travelers. This dataset isn't just a bunch of information it's a window into the vibrant and diverse community that makes Airbnb a unique way to explore the world.
#
# Thank You

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.
#
# The primary business objective of Airbnb is to conduct a thorough analysis for strategic decision-making. This involves:-
#
# - Understanding market dynamics through segmentation and localization,
# - Optimizing host engagement and performance,
# - Refining pricing strategies based on room types and minimum nights,
# - Assessing customer satisfaction through reviews, forecasting demand,
# - Managing availability effectively.
#
# By addressing these objectives, Airbnb aims to strengthen its market position, tailor user experiences, and foster business growth by staying responsive to evolving market dynamics and user preferences.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
data = pd.read_csv("C:/Users/Asus/Desktop/Airbnb NYC 2019.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
data.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
data.shape

# Here we can see that dataset has 48895  rows and 16 columns
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# Here we can see that columns like 'name', 'host_name', 'last_review', 'reviews_per_month' is haveing some null entries.

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
data[data.duplicated()].sum()
# Out:
# id                                0.0
# name                              0.0
# host_id                           0.0
# host_name                         0.0
# neighbourhood_group               0.0
# neighbourhood                     0.0
# latitude                          0.0
# longitude                         0.0
# room_type                         0.0
# price                             0.0
# minimum_nights                    0.0
# number_of_reviews                 0.0
# last_review                       0.0
# reviews_per_month                 0.0
# calculated_host_listings_count    0.0
# availability_365                  0.0
# dtype: float64

# %% [markdown]
# Here we can see that there are no duplicate entries in the dataset.

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

data.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values

# Filter columns with more than 0 null entries
columns_with_null = data.columns[data.isnull().sum() > 0]

# Create a bar chart to visualize null entries in selected columns
plt.figure(figsize=(10, 6))
bars = plt.bar(columns_with_null, data[columns_with_null].isnull().sum(), color='skyblue')

# Add text annotations for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.1, round(yval, 2), ha='center', va='bottom', color='black')

# Customize the plot
plt.title('Number of Null Entries in Columns with More Than 0 Null Entries')
plt.xlabel('Columns')
plt.ylabel('Number of Null Entries')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
# Display the plot
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer :-
#
# 1. The dataset comprises 48,895 entries with 16 columns, including 'id', 'name', 'host_id', and geographical data like 'latitude' and 'longitude'.
#
# 2. Data types of the dataset includes integers, floats, and objects, with columns like 'host_name', 'last_review' in object format.
#
# 3. Notable columns with null values are 'name', 'host_name', 'last_review', and 'reviews_per_month', with the latter two having a substantial number of null entries (10,052).
#
# 4. No duplicate entries are present in the dataset.
#
# 5. Data cleaning considerations will involve handling null values, dropping unnecessary columns, and addressing potential outliers in numeric columns.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
data.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here
#
# id: Unique identifier for each listing. Range from 2539 to 36487245.
#
# host_id: Unique identifier for each host. Range from 2438 to 274321313.
#
# latitude: Latitude coordinates of the listing location. Range is approximately from 40.499790 to 40.913060.
#
# longitude: Longitude coordinates of the listing location. Range is approximately from -74.244420 to -73.712990.
#
# price: Listing price per night. Range from 0 to 10,000.
#
# minimum_nights: Minimum number of nights required for booking. Range from 1 to 1250.
#
# number_of_reviews: Total number of reviews received for the listing. Range from 0 to 629.
#
# reviews_per_month: Average number of reviews received per month. Range from 0.01 to 58.5.
#
# calculated_host_listings_count: Count of listings managed by the host. Range from 1 to 327.
#
# availability_365: Number of days the listing is available for booking in a year. Range from 0 to 365.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Checking Unique Values for each variable.
data.nunique()
# Out:
# id                                48895
# name                              47905
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# Dropping id, host_name, last_review columns as they are unnecessary and will not impact our analysis and dataset
data.drop(['id','host_name','last_review'], axis=1, inplace=True)


# Filling null entries in name column with 'Unknown'
data['name'].fillna('Unknown', inplace=True)


# Filling null entries of reviews_per_month column with mean of all the other values of that column
mean_reviews_per_month = data['reviews_per_month'].mean()
data['reviews_per_month'].fillna(mean_reviews_per_month, inplace=True)


# Checking null entries after filling Null values
data.isnull().sum()
# Out:
# name                              0
# host_id                           0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.
#
# - Here i removed some columns  i,e. id, host_name, last_review columns as they aren't useful and will not impact our dataset and analysis.
# - There were some null entries in name column so filled those null entries with Unknown keyword
# - Also filled null entries in the reviews_per_month column with mean of all the other values of that column
#
# These manipulations contribute to data cleaning and preparation, creating a more streamlined dataset for analysis. The choice to fill null values with 'Unknown' and the mean is a common strategy to handle missing data in categorical and numerical columns, respectively.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

# Visualising who are the top 10 hosts
top_hosts = data['host_id'].value_counts().head(10)
top_hosts_id = list(map(lambda x : str(x) , top_hosts.keys()))
top_hosts_count = list(top_hosts)

plt.figure(figsize=(12, 6))
plt.bar(top_hosts_id, top_hosts_count, color = 'r')
plt.grid(True)
plt.title('Top 10 Hosts')
plt.xticks(rotation = 30)
plt.xlabel('Top Hosts ID')
plt.ylabel('Number of times they hosted')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# The specific chart chosen is a bar chart because it effectively displays the count of hosting occurrences for the top 10 hosts. Bar charts are suitable for comparing values between different categories, making it easy to identify the hosts with the highest hosting frequencies.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# - From this chart we can see that this host '219517861' is the best host with most number of times property hosted.
# - The chart reveals the top 10 hosts based on the count of hosting occurrences.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
#  Identifying the top hosts is valuable for Airbnb as it can lead to collaborations, recognition, and potential incentives for these hosts. Recognizing and rewarding top hosts could encourage them to continue providing exceptional service, contributing to positive customer experiences and loyalty.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

# Setting the style for Seaborn
sns.set(style="whitegrid")

# Creating a countplot for the 'neighbourhood_group' column
plt.figure(figsize=(12, 6))
sns.countplot(x='neighbourhood_group', data=data, palette='viridis' )

# Customizing the plot
plt.title('Distribution of Listings Across Neighborhood Groups')
plt.xlabel('Neighborhood Group')
plt.ylabel('Number of Listings')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# I choose a countplot because it effectively visualizes the distribution of categorical data. Here it helps to display the count of listings in each neighbourhood group. Countplots are clear and straightforward for such comparisons.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# - This chart provides insights into the distribution of listings across different neighborhood groups.
# - It allows us to see which neighborhood groups have a higher concentration of listings and which ones have fewer.
# - As here we can see that Manhattan has higher concentration of listing and Staten Island has lower number of listing.
# - This information is valuable for understanding the geographical distribution of Airbnb listings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Insights from the distribution of listings by neighborhood group can helps Airbnb identify popular or growing areas, allowing the platform to focus on marketing efforts, implementing targeted strategies, and potentially attract more hosts and guests to specific neighborhoods.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# Distribution of room_type
plt.figure(figsize=(12, 6))
sns.countplot(x = 'room_type', data= data, palette='pastel')
plt.title('Distribution of Room Type')

# Customizing the plot
plt.xlabel('Room Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# - I uses the count plot to visualize the distribution of the room_type variable.
# - It is suitable for displaying the frequency or count of categorical data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# - The chart reveals the distribution of different room types in the dataset.
# - Each bar represents a specific room type, and the height of the bar indicates the count (frequency) of the room type.
# - Here we can see that 'Entire home/apt' Room type has higher number of frequency and 'Shared room' has lower frequency.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# - This visualization can help Airbnb tailor marketing strategies, improve user experience, and optimize resource allocation.
# - understanding distribution allows the platform to highlight and promote the most popular room types.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

# Setting figure size of the plot
fig = plt.figure(figsize = (15,10))
ax = fig.gca()      # Getting the current Axes instance
data.hist(ax=ax)    # Creating a histogram for each column in the DataFrame
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# - I created histograms for each numerical column in the DataFrame 'data'.
# - Here i visualise the each numerical column in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# - The chart provides a visual overview of the distribution of each numeircal variable in the dataset.
# - The visualization of histograms provides a comprehensive overview of data distributions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# - The insights from these histograms can be helpful in taking business decisions related to identifying potential patterns, trends, or outliers.
# - Thid knowledge can be used to optimize features, refining marketing strategies and enhance user experience.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

# Visualizing Distribution of Listing Prices
plt.figure(figsize=(10, 6))
sns.histplot(data['price'], bins=30, color='b')
plt.title('Distribution of Listing Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# - I use histogram to visualize the distribution of listing prices.
# - I have done the visualization of listing prices because as aggresive pricing is important to enhance user experience.
# - It is suitable for displaying the distribution of a continuous variable as in this case, the prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# - The histogram provides insights into the distribution of listing prices.
# - Each bar represents a price range, and the height of the bar indicates the frequency within the range.
# - Here we can visualize that prize range $0 to approx $350 has higher frequency more than 40000.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# - The insights gained from this visualization can inform pricing strateies on the platform.
# - Understanding distribution allows Airbnb to set competetive pricing, identify price ranges that attract more bookings, and optimize price structures for hosts.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# Visualising distribution of prices for each neighberhood_group

# As we above see from data.describe statistical table that we have some extreme values, so i removed them for the sake of a better visualization.
df = data[data.price<1000]
plt.figure(figsize=(16,10))
sns.violinplot(x="neighbourhood_group", y="price", data=df, scale="width",palette="Set3")
plt.title('Density and distribution of prices for each neighbourhood_group')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# - Here i use violin plot as it is suitable for displaying the distribution of a continuous variable across different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# - This plot reveals the density and distribution of prices within each neighnorhood group.
# - Each violin plot represents a neighborhood group, and the width of the plot corresponds to the density of prices.
# - Here we can observe that Manhattan has the highest range of prices for the listings with approx $140 to $150 price as average followed by Brooklyn with approx $90 to $100 as aveage.
# - This plot reveals that Manhattan has high standard of livings and Bronx has low standard of living.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# - This visualization can help Airbnb make informed decisions related to pricing strategies.
# - This visualization enables the platform to tailor pricing recommendations, promotions and marketing efforts to specific regions, enhancing user engagement and satisfaction.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# Visualising distribution of reviews_per_month for each neighberhood_group

plt.figure(figsize = (10,6))
plt.title('Density and distribution of reviews_per_month for each neighbourhood_group')
sns.barplot(x='neighbourhood_group', y="reviews_per_month", data=data)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# - Here i visualize the distribution of the variable 'reviews_per_month' across different neighborhood groups using bar plot which is suitable for comparing the mean or aggregate values of a numerical variable across different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# - The chart provides insights into the average reviews_per_month for each neighborhood_group.
# - Each bar represents a neighborhood group, and the height of the bar indicates the average number of reviews per month.
# - Here we can observe that Queens has higher number of review activity compare to other and standard locations like Brooklyn and Manhattan has similar number of reviews actvity.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# - This visualization can inform business decisions related to customer engagement and satisfaction.
# - Understanding the distribution of reviews_per_month across neighborhood groups allows Airbnb to identify areas with higher or lower review activity.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# Visualizing distribution of price for each room_type

plt.figure(figsize = (10,6))
sns.barplot(x='room_type', y="price", data=data) 
plt.title('Density and distribution of price for each room_type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# - Here a visualize the distribution of prices across different room types using bar plot.
# - It provides a clear comparison of price distributiions for each room type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# - The chart provides insights into the average prices for each room type.
# - This visualization allows for easy comparison of pricing across different types of rooms.
# - As here we can see that the difference between average price of private room and shared room is not much but there is a huge difference in Entire home?apt room type compare to other room types.
# - This plot clearly states that enire home/apt room_type are costly.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# - The insights gained from this visualization can inform pricing strategies for different roome types.
# - Understanding this distribution of prices across room types allows Airbnb to set competitive and market driven pricing

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# Visualizing distribution of minimum_nights for each room type

plt.figure(figsize = (10,6))
plt.title('Density and Distribution of minimum_nights for each room type')
sns.barplot(x = 'room_type', y = 'minimum_nights', data = data)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# Here i used bar plot which is appropriate for comparing the average or aggregate values of a numerical variable across different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# - This visualization provides insights into the average minimum nights required for each room type.
# - It allows for a quick assessment of the minimum nights requirement across different types of rooms.
# - In this plot we can observe that Average of minimum night a person has to spend in Entire home/apt room type is more than other room types listed on Airbnb i,e. private room and shared room.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# - This visualization can inform pricing strategies on the platform.
# - It allows Airbnb to set competitive pricing, identify price ranges that attract more bookings.
# - If there are significant outliers or a skewed distribution, it might indicate challenges related to pricing.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

plt.figure(figsize=(16,10))
plt.title('Relation of Price to Availability Across Listings')
sns.lineplot(x = 'availability_365', y = 'price', data = data, color = 'r')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# - I uses line plot to visualize the relationship between the availability of listings and their corresponsing prices.
# - It is suitable for showing the trend between two continuous range.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# - Here i visualize how the price of listings varies concerning their availability throughout the year.
# - Each point on the line represents a listing, and the position on the x-axis corresponds to the availability, while the position on hte y-axis represents the listing price.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# - The insights gained from this visualization can inform pricing strategies based on availability trends.
# - Airbnb can identify patterns where pricing adjustments may be beneficial during high or low availability periods.

# %% [markdown]
# #### Chart - 11

# %%
neighbourhood_group_count = data['neighbourhood_group'].value_counts()
neighbourhood_group_count
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
# Chart - 11 visualization code

# Visualization of Geographical Distribution of listings.

plt.figure(figsize= (10,6))
plt.title('Geographical Distribution of Listings by Neighbourhood Group')

sns.scatterplot(data.longitude,data.latitude,hue=data.neighbourhood_group)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# - Here i used scatter plot for the visualization of geographical distribution of listings based on latitude and longitude.
# - Scatter plot is effective for displaying the spatial distribution of data points.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# - The scatter plot provides insights of the geographical locations of listings.
# - The color variation distinguishes the listings belonging to different neighbourhood groups.
# - Above we have already seen that Manhattan and Brooklyn has higher number of listings but as per plot we can see that a small area has higher number of listings in both Manhattan and Brooklyn which indicates higher market density.
# - Here we also observe that queens neighbourhood has just 5666 listings in a widely spread area compared to Manhattan and Brooklyn

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# - This visualization can help taking business decisions related to marketing and regional strategies.
# - Understanding geographical distribution can help in targeting specific audiences and optimizing services based on regional preferences.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

plt.figure(figsize=(12, 8))
plt.title('Scatter Plot for minimum_nights and calculated_host_listings_count by Neighbourhood Group')
sns.scatterplot(x='minimum_nights', y='calculated_host_listings_count', hue='neighbourhood_group', data=data, palette='Set2', alpha=0.7)
plt.xlabel('Minimum Nights')
plt.ylabel('Calculated Host Listings Count')
plt.legend(title='Neighbourhood Group')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# Here i choose scatter plot as they are helpful to visually represent the relationship between two numerical columns and categorize data points by different hues.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# - Here scatter plot proivides the relationship between the minimum nights required for bookings and the count of listings managed by hosts.
# - Each point on the plot represents a listing, and the color indicates the neighbourhood group.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# - The insights gained from this visualization can guide business decisions related to host management.
# - Here Airbnb can identify areas where hosts manage a higher number of listings while offering flexible minimum nights.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

plt.figure(figsize=(10,7))
plt.title('Bar Plot of Average Prices by Neighbourhood Group and Room Type')
sns.barplot(x = "neighbourhood_group", y = "price", hue = "room_type", data = df)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# - Here i used bar plot to display the average prices categorized by both neighbourhood_group and room_type.
# - Here hues for room types provides a clear comparison of average prices across multiple categorical variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# - The bar plot offers insights into the average prices for different room types (room_type) within each neighbourhood group (neighbourhood_group).
# - Each bar represents a combination of neighbourhood group, room type, and the corresponding average price.
# - Here we can observe that from the plot we can definietely say that Manhattan is a standard location as the price of each room type is more compare to room type in other neighbouhood groups.
# - Prices of room type in Queens, Staten Island, Bronx are approximately similar.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# - The insights gained from this visualization can inform pricing strategies for different room types within specific neighbourhoods.
# - Airbnb can tailor pricing promotions, discounts, or marketing efforts based on the observed patterns.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

f,ax=plt.subplots(figsize=(12,12))
plt.title('Correlation Heat Map')
sns.heatmap(data.corr(),annot=True,linewidths=5,fmt='.1f',ax=ax)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# The heatmap of the correlation matrix is used to visualize the pairwise correlations between different numerical variables in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# - The heatmap provides insights into the correlation patterns between various numerical variables in the dataset.
# - This visualization allows for a quick identification of variables that have strong positive or negative correlations.
# - Here we can observe that number_of_reviews and reviews_per_month both these columns are highly correlated compared to other columns.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# Selecting relevant numerical columns for the pair plot
numerical_columns = ['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']

# Createing a pair plot
plt.figure(figsize=(12,12))
sns.pairplot(data[numerical_columns])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# - The pair plot is used to visualize the relationships and distributions between numerical variables in the dataset.
# - This chart type is particularly useful for identifying patterns, trends, and potential correlations between pairs of variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The pair plot provides a comprehensive view of the relationships between the selected numerical variables. Each scatterplot shows the relationship between two variables, and histograms along the diagonal display the distribution of individual variables.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.
#
# To achieve's Airbnb's business goals here are some recommendations:
# - Provide training and support to hosts. Help them in makeing their listings better and communicate effectilvely with guests.
# - Use dynamic pricing adjust prices based on factors like local demand, room types. This is gonna help hosts earn more and guests find good deals.
# - Read guest reviews to know what they like or don't improve services based on the feedback.
# - Help hosts to optimize minimum nights and busy times to keep listings open when guests want to book.
# - Try new ideas and use latest technology. Regularly update services to stay ahead in the industry.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.
#
# This dataset is appeared to be very fruitful dataset with variety of columns in which we deep dive to explore each column presented.
#
# - First, I had found that some of the hosts take good advantage of the Airbnb platform and provide the most listings, I found that our top host has listed more than 300 rooms on the platform.
# - After that, I found the locations with most number of listings, Manhattan and Brooklyn are the neighbourhoods with more than 20000 listings.
# - After that, I looked into the room_type column from there i found that "Entire home/apt" and "Private room" are the popular room types with more than 20000 listings on Airbnb platform.
# - After that, I looked onto the overview of the distribution of each numerical varaible in the dataset which provides a comprehensive overview of data distributions.
# - After that, I looked into the distribution of price which provides us information that most of listings on the Airbnb is in the range or $0 to $400.
# - After that, I proceed with analyzing price and neighbouhood group lising densities and what areas were more popular than another.
# - After that, I looked into the price of and analysed that 'Entire home/apt" room type is expensive compared to private room and shared room.
# - Next, I put good use of latitude and longitude columns and used to create a scatter plot color-coded by neighbourhood_group of the listings.
# - Further, I analyzed how price of different room types varying in different locations.
# - Lastly i looked into the pair plot and the heatmap of the dataset and looked into the correlation of the variables in the dataset which allow us quick identification of columns with strong positive and negative correlation.
# - While doing this data analysis i found out a lot of informative things and it would be nice if dataset will have couple of additional feaures such as (0-5 stars) reviews for each listing, addition of these feature would help me to determine the best reviewed host for NYC along with number_of_review column that is provided.
# - Overall, I discovered a very good number of interesting relationships between features and explained each step of the process.
#
# Hope you find it useful, Thank You.
# Navjot Singh

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
